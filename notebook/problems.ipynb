# %% [markdown]
# # Probability distribution problems

# %% [markdown]
# ## Binomial distribution
#
# In probability theory and statistics, the normial distribution is the discrete probability distribution that gives only two possible results in an experiment, for example, when you flip a coin it can by either head or tails.

# %%
from scipy.stats import binom

# Define all the probability functions related to this distribution

def dbinom(x, size, prob = 0.5):
    """
    Calculates the point estimate of the normial distribution
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Generates random variables from the binomial distribution
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Binomial(10, 0.2) distribution where n = 10 is the number of trials and p = 0.2 is the probability of success in a single trial.
import numpy as np
np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Exercise 1
#
# Write the above functions but for both normal and uniform distributions.

# %% [markdown]
# ## Normal distribution
#
# In probability theory and statistics, the normial distribution is the discrete probability distribution that gives a range of results in an experiment, for example, the heitgh of population around the mean.

# %%
# Define all the probability functions related to this distribution
from scipy.stats import norm
def dnorm(x=0, scale=1, loc = 0):
    """
    Calculates the point estimate of the normal distribution
    """
    result = norm.pdf(x = x, scale = scale, loc = loc)
    return result

def pnorm(x=0, scale=1, loc = 0):
    """
    Calculates the cumulative of the normal distribution
    """
    result = norm.cdf(x = x, scale = scale, loc = loc)

    return result

def qnorm(x=0, scale=1, loc = 0):
    """
    Calculates the quantile function from the binomial distribution
    """
    result = norm.ppf(q = x, scale = scale, loc = loc)

    return result

def rnorm(x=0, scale=1, loc = 0):
    """
    Generates random variables from the binomial distribution
    """
    result = norm.rvs(n = size, p = prob, size = n)

    return result

# %%
# Binomial(10, 0.2) distribution where n = 10 is the number of trials and p = 0.2 is the probability of success in a single trial.
import numpy as np
np.random.seed(42)

x = np.linspace(-1, 1, num=100)
pdf_norm = dnorm(x,loc=0,scale=1)
cdf_norm = pnorm(x,loc=0,scale=1)
ppf_norm = qnorm(x,loc=0,scale=1)

#print(f"Probability that a Binomial(10, 0.2) takes the value 2: {pdf_norm}")
plt.plot(x, pdf_norm)
plt.title('Normal Distribution')
plt.xlabel('Values')
plt.ylabel('Probability Density')
plt.show()

plt.plot(x, cdf_norm)
plt.title('Normal Distribution')
plt.xlabel('Values')
plt.ylabel('Probability Density')
plt.show()


plt.plot(x, ppf_norm)
plt.title('Normal Distribution')
plt.xlabel('Values')
plt.ylabel('Probability Density')
plt.show()
#print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
#print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
#print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")

# %%
# Define all the probability functions related to this distribution
from scipy.stats import uniform
def duninorm(x=0, scale=1, loc = 0):
    """
    Calculates the point estimate of the uniform distribution
    """
    result = uniform.pdf(x = x, scale = scale, loc = loc)
    return result

def puninorm(x=0, scale=1, loc = 0):
    """
    Calculates the cumulative of the uniform distribution
    """
    result = uniform.cdf(x = x, scale = scale, loc = loc)

    return result

def quninorm(x=0, scale=1, loc = 0):
    """
    Calculates the quantile function from the uniform distribution
    """
    result = uniform.ppf(q = x, scale = scale, loc = loc)

    return result

def runinorm(x=0, scale=1, loc = 0):
    """
    Generates random variables from the uniform distribution
    """
    result = uniform.rvs(n = size, p = prob, size = n)

    return result


# Binomial(10, 0.2) distribution where n = 10 is the number of trials and p = 0.2 is the probability of success in a single trial.
import numpy as np
np.random.seed(42)

def rununiform(x): return uniform(0,1).rvs(x)

x = rununiform(1000)

pdf_uninorm = duninorm(x,loc=0,scale=1)
cdf_uninorm = puninorm(x,loc=0,scale=1)
ppf_uninorm = quninorm(x,loc=0,scale=1)

#print(f"Probability that a Binomial(10, 0.2) takes the value 2: {pdf_norm}")
plt.plot(x, pdf_uninorm)
plt.title('Normal Distribution')
plt.xlabel('Values')
plt.ylabel('Probability Density')
plt.show()

plt.plot(x, cdf_uninorm)
plt.title('Normal Distribution')
plt.xlabel('Values')
plt.ylabel('Probability Density')
plt.show()


plt.plot(x, ppf_uninorm)
plt.title('Normal Distribution')
plt.xlabel('Values')
plt.ylabel('Probability Density')
plt.show()
#print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
#print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
#print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
